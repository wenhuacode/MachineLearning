# %% [markdown]
# ### 梯度下降法模拟

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plot_x = np.linspace(-1, 6, 141)
plot_x
# Out:
# array([-1.  , -0.95, -0.9 , -0.85, -0.8 , -0.75, -0.7 , -0.65, -0.6 ,
#        -0.55, -0.5 , -0.45, -0.4 , -0.35, -0.3 , -0.25, -0.2 , -0.15,
#        -0.1 , -0.05,  0.  ,  0.05,  0.1 ,  0.15,  0.2 ,  0.25,  0.3 ,
#         0.35,  0.4 ,  0.45,  0.5 ,  0.55,  0.6 ,  0.65,  0.7 ,  0.75,
#         0.8 ,  0.85,  0.9 ,  0.95,  1.  ,  1.05,  1.1 ,  1.15,  1.2 ,
#         1.25,  1.3 ,  1.35,  1.4 ,  1.45,  1.5 ,  1.55,  1.6 ,  1.65,
#         1.7 ,  1.75,  1.8 ,  1.85,  1.9 ,  1.95,  2.  ,  2.05,  2.1 ,
#         2.15,  2.2 ,  2.25,  2.3 ,  2.35,  2.4 ,  2.45,  2.5 ,  2.55,
#         2.6 ,  2.65,  2.7 ,  2.75,  2.8 ,  2.85,  2.9 ,  2.95,  3.  ,
#         3.05,  3.1 ,  3.15,  3.2 ,  3.25,  3.3 ,  3.35,  3.4 ,  3.45,
#         3.5 ,  3.55,  3.6 ,  3.65,  3.7 ,  3.75,  3.8 ,  3.85,  3.9 ,
#         3.95,  4.  ,  4.05,  4.1 ,  4.15,  4.2 ,  4.25,  4.3 ,  4.35,
#         4.4 ,  4.45,  4.5 ,  4.55,  4.6 ,  4.65,  4.7 ,  4.75,  4.8 ,
#         4.85,  4.9 ,  4.95,  5.  ,  5.05,  5.1 ,  5.15,  5.2 ,  5.25,
#         5.3 ,  5.35,  5.4 ,  5.45,  5.5 ,  5.55,  5.6 ,  5.65,  5.7 ,
#         5.75,  5.8 ,  5.85,  5.9 ,  5.95,  6.  ])

# %%
plot_y = (plot_x - 2.5) ** 2 -1

# %%
plot_y
# Out:
# array([11.25  , 10.9025, 10.56  , 10.2225,  9.89  ,  9.5625,  9.24  ,
#         8.9225,  8.61  ,  8.3025,  8.    ,  7.7025,  7.41  ,  7.1225,
#         6.84  ,  6.5625,  6.29  ,  6.0225,  5.76  ,  5.5025,  5.25  ,
#         5.0025,  4.76  ,  4.5225,  4.29  ,  4.0625,  3.84  ,  3.6225,
#         3.41  ,  3.2025,  3.    ,  2.8025,  2.61  ,  2.4225,  2.24  ,
#         2.0625,  1.89  ,  1.7225,  1.56  ,  1.4025,  1.25  ,  1.1025,
#         0.96  ,  0.8225,  0.69  ,  0.5625,  0.44  ,  0.3225,  0.21  ,
#         0.1025,  0.    , -0.0975, -0.19  , -0.2775, -0.36  , -0.4375,
#        -0.51  , -0.5775, -0.64  , -0.6975, -0.75  , -0.7975, -0.84  ,
#        -0.8775, -0.91  , -0.9375, -0.96  , -0.9775, -0.99  , -0.9975,
#        -1.    , -0.9975, -0.99  , -0.9775, -0.96  , -0.9375, -0.91  ,
#        -0.8775, -0.84  , -0.7975, -0.75  , -0.6975, -0.64  , -0.5775,
#        -0.51  , -0.4375, -0.36  , -0.2775, -0.19  , -0.0975,  0.    ,
#         0.1025,  0.21  ,  0.3225,  0.44  ,  0.5625,  0.69  ,  0.8225,
#         0.96  ,  1.1025,  1.25  ,  1.4025,  1.56  ,  1.7225,  1.89  ,
#         2.0625,  2.24  ,  2.4225,  2.61  ,  2.8025,  3.    ,  3.2025,
#         3.41  ,  3.6225,  3.84  ,  4.0625,  4.29  ,  4.5225,  4.76  ,
#         5.0025,  5.25  ,  5.5025,  5.76  ,  6.0225,  6.29  ,  6.5625,
#         6.84  ,  7.1225,  7.41  ,  7.7025,  8.    ,  8.3025,  8.61  ,
#         8.9225,  9.24  ,  9.5625,  9.89  , 10.2225, 10.56  , 10.9025,
#        11.25  ])

# %%
plt.plot(plot_x, plot_y, color='g')

# %%
def dJ(theta):
    return 2 * (theta - 2.5)

# %%
def J(theta):
    return (theta - 2.5) ** 2 -1

# %%
eta = 0.2
epsilon = 1E-8

theta = 0.0
while True:
    gradient = dJ(theta)
    last_theta = theta
    theta = theta - eta * gradient

    if(abs(J(theta) - J(last_theta)) < epsilon):
        break
print(theta)
print(J(theta))
# Out:
# 2.499945157623399
# -0.9999999969923137

# %%
theta = 0.0
theta_history = [theta]
while True:
    gradient = dJ(theta)
    last_theta = theta
    theta = theta - eta * gradient
    theta_history.append(theta)

    if(abs(J(theta) - J(last_theta)) < epsilon):
        break

plt.plot(plot_x, J(plot_x))
plt.plot(np.array(theta_history), J(np.array(theta_history)), color='r', marker='+')

# %%
len(theta_history)
# Out:
# 22

# %%
def gradient_descent(initial_theta, eta, epsilon=1e-8):
    theta = initial_theta
    theta_history.append(initial_theta)

    while True:
        gradient = dJ(theta)
        last_theta = theta
        theta = theta - eta * gradient
        theta_history.append(theta)

        if(abs(J(theta) - J(last_theta)) < epsilon):
            break
            
def plot_theta_history():
    plt.plot(plot_x, J(plot_x))
    plt.plot(np.array(theta_history), J(np.array(theta_history)), color='r', marker='+')

# %%
eta = 0.01
theta_history = []
gradient_descent(0., eta)
plot_theta_history()

# %%
len(theta_history)
# Out:
# 424

# %%
eta = 0.001
theta_history = []
gradient_descent(0., eta)
plot_theta_history()

# %%
len(theta_history)
# Out:
# 3682

# %%
eta = 0.5
theta_history = []
gradient_descent(0., eta)
plot_theta_history()

# %%
len(theta_history)
# Out:
# 3

# %%
def J(theta):
    try:
        return (theta - 2.5) ** 2 -1
    except:
        return float('inf')

# %%
eta = 1
theta_history = []
gradient_descent(0., eta)
plot_theta_history()

# %%
def gradient_descent(initial_theta, eta, n_iters=1e4, epsilon=1e-8):
    theta = initial_theta
    theta_history.append(initial_theta)
    i_iter = 0

    while i_iter < n_iters:
        gradient = dJ(theta)
        last_theta = theta
        theta = theta - eta * gradient
        theta_history.append(theta)

        if(abs(J(theta) - J(last_theta)) < epsilon):
            break

        i_iter += 1

# %%
eta = 1.1
theta_history = []
gradient_descent(0., eta)
plot_theta_history()
# Out:
# C:\Users\wh\AppData\Local\Temp\ipykernel_21760\3074955857.py:3: RuntimeWarning: overflow encountered in square
#   return (theta - 2.5) ** 2 -1
# C:\Users\wh\Envs\math\lib\site-packages\matplotlib\ticker.py:2098: RuntimeWarning: overflow encountered in multiply
#   steps = self._extended_steps * scale
# C:\Users\wh\Envs\math\lib\site-packages\matplotlib\ticker.py:2133: RuntimeWarning: overflow encountered in multiply
#   ticks = np.arange(low, high + 1) * step + best_vmin
# Error in callback <function _draw_all_if_interactive at 0x000001EB0FBF9900> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File ~\Envs\math\lib\site-packages\matplotlib\pyplot.py:197, in _draw_all_if_interactive()
#     195 def _draw_all_if_interactive() -> None:
#     196     if matplotlib.is_interactive():
# --> 197         draw_all()
#
# File ~\Envs\math\lib\site-packages\matplotlib\_pylab_helpers.py:132, in Gcf.draw_all(cls, force)
#     130 for manager in cls.get_all_fig_managers():
#     131     if force or manager.canvas.figure.stale:
# --> 132         manager.canvas.draw_idle()
#
# File ~\Envs\math\lib\site-packages\matplotlib\backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~\Envs\math\lib\site-packages\matplotlib\backends\backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File ~\Envs\math\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\Envs\math\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Envs\math\lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~\Envs\math\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\Envs\math\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Envs\math\lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~\Envs\math\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\Envs\math\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Envs\math\lib\site-packages\matplotlib\axis.py:1387, in Axis.draw(self, renderer, *args, **kwargs)
#    1384     return
#    1385 renderer.open_group(__name__, gid=self.get_gid())
# -> 1387 ticks_to_draw = self._update_ticks()
#    1388 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1390 for tick in ticks_to_draw:
#
# File ~\Envs\math\lib\site-packages\matplotlib\axis.py:1276, in Axis._update_ticks(self)
#    1271 """
#    1272 Update ticks (position and labels) using the current data interval of
#    1273 the axes.  Return the list of ticks that will be drawn.
#    1274 """
#    1275 major_locs = self.get_majorticklocs()
# -> 1276 major_labels = self.major.formatter.format_ticks(major_locs)
#    1277 major_ticks = self.get_major_ticks(len(major_locs))
#    1278 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File ~\Envs\math\lib\site-packages\matplotlib\ticker.py:215, in Formatter.format_ticks(self, values)
#     213 def format_ticks(self, values):
#     214     """Return the tick labels for all the ticks at once."""
# --> 215     self.set_locs(values)
#     216     return [self(value, i) for i, value in enumerate(values)]
#
# File ~\Envs\math\lib\site-packages\matplotlib\ticker.py:706, in ScalarFormatter.set_locs(self, locs)
#     704     self._compute_offset()
#     705 self._set_order_of_magnitude()
# --> 706 self._set_format()
#
# File ~\Envs\math\lib\site-packages\matplotlib\ticker.py:799, in ScalarFormatter._set_format(self)
#     796 if len(self.locs) < 2:
#     797     # We needed the end points only for the loc_range calculation.
#     798     locs = locs[:-2]
# --> 799 loc_range_oom = int(math.floor(math.log10(loc_range)))
#     800 # first estimate:
#     801 sigfigs = max(0, 3 - loc_range_oom)
#
# OverflowError: cannot convert float infinity to integer
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# File ~\Envs\math\lib\site-packages\IPython\core\formatters.py:340, in BaseFormatter.__call__(self, obj)
#     338     pass
#     339 else:
# --> 340     return printer(obj)
#     341 # Finally look for special method names
#     342 method = get_real_method(obj, self.print_method)
#
# File ~\Envs\math\lib\site-packages\IPython\core\pylabtools.py:152, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149     from matplotlib.backend_bases import FigureCanvasBase
#     150     FigureCanvasBase(fig)
# --> 152 fig.canvas.print_figure(bytes_io, **kw)
#     153 data = bytes_io.getvalue()
#     154 if fmt == 'svg':
#
# File ~\Envs\math\lib\site-packages\matplotlib\backend_bases.py:2164, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2161     # we do this instead of `self.figure.draw_without_rendering`
#    2162     # so that we can inject the orientation
#    2163     with getattr(renderer, "_draw_disabled", nullcontext)():
# -> 2164         self.figure.draw(renderer)
#    2165 if bbox_inches:
#    2166     if bbox_inches == "tight":
#
# File ~\Envs\math\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\Envs\math\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Envs\math\lib\site-packages\matplotlib\figure.py:3154, in Figure.draw(self, renderer)
#    3151         # ValueError can occur when resizing a window.
#    3153 self.patch.draw(renderer)
# -> 3154 mimage._draw_list_compositing_images(
#    3155     renderer, self, artists, self.suppressComposite)
#    3157 for sfig in self.subfigs:
#    3158     sfig.draw(renderer)
#
# File ~\Envs\math\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\Envs\math\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Envs\math\lib\site-packages\matplotlib\axes\_base.py:3070, in _AxesBase.draw(self, renderer)
#    3067 if artists_rasterized:
#    3068     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3070 mimage._draw_list_compositing_images(
#    3071     renderer, self, artists, self.figure.suppressComposite)
#    3073 renderer.close_group('axes')
#    3074 self.stale = False
#
# File ~\Envs\math\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\Envs\math\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\Envs\math\lib\site-packages\matplotlib\axis.py:1387, in Axis.draw(self, renderer, *args, **kwargs)
#    1384     return
#    1385 renderer.open_group(__name__, gid=self.get_gid())
# -> 1387 ticks_to_draw = self._update_ticks()
#    1388 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1390 for tick in ticks_to_draw:
#
# File ~\Envs\math\lib\site-packages\matplotlib\axis.py:1276, in Axis._update_ticks(self)
#    1271 """
#    1272 Update ticks (position and labels) using the current data interval of
#    1273 the axes.  Return the list of ticks that will be drawn.
#    1274 """
#    1275 major_locs = self.get_majorticklocs()
# -> 1276 major_labels = self.major.formatter.format_ticks(major_locs)
#    1277 major_ticks = self.get_major_ticks(len(major_locs))
#    1278 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# File ~\Envs\math\lib\site-packages\matplotlib\ticker.py:215, in Formatter.format_ticks(self, values)
#     213 def format_ticks(self, values):
#     214     """Return the tick labels for all the ticks at once."""
# --> 215     self.set_locs(values)
#     216     return [self(value, i) for i, value in enumerate(values)]
#
# File ~\Envs\math\lib\site-packages\matplotlib\ticker.py:706, in ScalarFormatter.set_locs(self, locs)
#     704     self._compute_offset()
#     705 self._set_order_of_magnitude()
# --> 706 self._set_format()
#
# File ~\Envs\math\lib\site-packages\matplotlib\ticker.py:799, in ScalarFormatter._set_format(self)
#     796 if len(self.locs) < 2:
#     797     # We needed the end points only for the loc_range calculation.
#     798     locs = locs[:-2]
# --> 799 loc_range_oom = int(math.floor(math.log10(loc_range)))
#     800 # first estimate:
#     801 sigfigs = max(0, 3 - loc_range_oom)
#
# OverflowError: cannot convert float infinity to integer

# %%
len(theta_history)
# Out:
# 10001

# %%
eta = 1
theta_history = []
gradient_descent(0., eta, n_iters=5)
plot_theta_history()
