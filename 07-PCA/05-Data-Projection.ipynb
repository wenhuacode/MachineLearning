# %% [markdown]
# ### 从高维数据向低维数据的映射

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.empty((100, 2))
X[:, 0] = np.random.uniform(0., 100., size=100)
X[:, 1] = 0.75 * X[:, 0] + 3. + np.random.normal(0, 10., size=100)

# %%
from PCA import PCA

pca = PCA(n_components=2)
pca.fit(X)
# Out:
# PCA(n_components=2)

# %%
pca.components_
# Out:
# array([[ 0.76945278,  0.6387037 ],
#        [-0.63869996,  0.76945589]])

# %%
pca = PCA(n_components=1)

# %%
pca.fit(X)
# Out:
# PCA(n_components=1)

# %%
X_reduction = pca.transform(X)

# %%
X_reduction.shape
# Out:
# (100, 1)

# %%
x_restore = pca.inverse_transform(X_reduction)

# %%
x_restore.shape
# Out:
# (100, 2)

# %%
plt.scatter(X[:, 0], X[:, 1], color='b', alpha=0.5)
plt.scatter(x_restore[:, 0], x_restore[:, 1], color='r', alpha=0.5)
plt.show()

# %%
x_restore[:10]
# Out:
# array([[87.85703676, 72.92793321],
#        [73.07781173, 60.66006741],
#        [40.49538762, 33.61421045],
#        [73.44853938, 60.96779918],
#        [76.59791139, 63.58201428],
#        [19.77661316, 16.41607293],
#        [74.12340988, 61.52799234],
#        [ 0.3610709 ,  0.29971594],
#        [77.39202441, 64.24118767],
#        [86.36065681, 71.68582556]])

# %% [markdown]
# ### scikit-lrarn 中的PCA

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=1)
pca.fit(X)
# Out:
# PCA(n_components=1)

# %%
pca.components_
# Out:
# array([[-0.76945282, -0.63870365]])

# %%
X_reduction = pca.transform(X)

# %%
X_reduction.shape
# Out:
# (100, 1)

# %%
X_restore = pca.inverse_transform(X_reduction)

# %%
X_restore.shape
# Out:
# (100, 2)

# %%
plt.scatter(X[:, 0], X[:, 1], color='b', alpha=0.5)
plt.scatter(x_restore[:, 0], x_restore[:, 1], color='r', alpha=0.5)
plt.show()
